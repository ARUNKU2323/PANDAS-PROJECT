# %%
import pandas as pd

# %%
df=pd.read_excel("/content/mega_data_cleaning_dataset.xlsx")
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121               NaN  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#       Customer_ID              Name  Age  Gender            Country  \
# 0            1191     Larry Wallace   31   Other                NaN
# 1            8287      Shawn Palmer   20    Male             Uganda
# 2            6574     Daniel Cortez  105     Mle         Tajikistan
# 3            3377      Cindy Barber  100  Female              Chile
# 4            5107     William Patel  110     Mle        Timor-Leste
# ...           ...               ...  ...     ...                ...
# 9991         2919      Tyler Hunter   44  Female               Guam
# 9993         8538      Harry Carter  108  Female            Tokelau
# 9994         1905     Deborah Young  128       f             Tuvalu
# 9998         8121               NaN  110    Male  Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle            Albania
#
#           State                City                               Email  \
# 0      Arkansas           Janetfort  gonzalezbrandi@shaffer-lambert.com
# ...

# %%
df = df.drop_duplicates(subset='Customer_ID', keep='first')
df
# Out:
#       Customer_ID              Name  Age  Gender            Country  \
# 0            1191     Larry Wallace   31   Other                NaN
# 1            8287      Shawn Palmer   20    Male             Uganda
# 2            6574     Daniel Cortez  105     Mle         Tajikistan
# 3            3377      Cindy Barber  100  Female              Chile
# 4            5107     William Patel  110     Mle        Timor-Leste
# ...           ...               ...  ...     ...                ...
# 9991         2919      Tyler Hunter   44  Female               Guam
# 9993         8538      Harry Carter  108  Female            Tokelau
# 9994         1905     Deborah Young  128       f             Tuvalu
# 9998         8121               NaN  110    Male  Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle            Albania
#
#           State                City                               Email  \
# 0      Arkansas           Janetfort  gonzalezbrandi@shaffer-lambert.com
# ...

# %%
df = df.drop_duplicates(subset='Email', keep='first')
df
# Out:
#       Customer_ID              Name  Age  Gender            Country  \
# 0            1191     Larry Wallace   31   Other                NaN
# 1            8287      Shawn Palmer   20    Male             Uganda
# 2            6574     Daniel Cortez  105     Mle         Tajikistan
# 3            3377      Cindy Barber  100  Female              Chile
# 4            5107     William Patel  110     Mle        Timor-Leste
# ...           ...               ...  ...     ...                ...
# 9991         2919      Tyler Hunter   44  Female               Guam
# 9993         8538      Harry Carter  108  Female            Tokelau
# 9994         1905     Deborah Young  128       f             Tuvalu
# 9998         8121               NaN  110    Male  Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle            Albania
#
#           State                City                               Email  \
# 0      Arkansas           Janetfort  gonzalezbrandi@shaffer-lambert.com
# ...

# %%
df = df.drop_duplicates(subset='Product_ID', keep='first')
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675               NaN   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3034         3786      Karen Miller   22       f                France
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
# 3298         5796        Angel Hood   53     Mle                   NaN
#
#                State                City                               Email  \
# ...

# %%
df['Name'] = df['Name'].fillna('Unknown')
df
# Out:
# /tmp/ipython-input-2059556363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'] = df['Name'].fillna('Unknown')
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# ...

# %%
df['Email'] = df['Email'].fillna('noemail@example.com')
df
# Out:
# /tmp/ipython-input-900248394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Email'] = df['Email'].fillna('noemail@example.com')
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# ...

# %%
df['Product_Name'] = df['Product_Name'].fillna('Misc')
df
# Out:
# /tmp/ipython-input-1685545772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Product_Name'] = df['Product_Name'].fillna('Misc')
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# ...

# %%
df['Category'] = df['Category'].fillna('Misc')
df
# Out:
# /tmp/ipython-input-1577046602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category'] = df['Category'].fillna('Misc')
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# ...

# %%
df.groupby('Product_ID')['Feedback_Score'].transform(lambda x: x.fillna(x.median()))
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3034         3786      Karen Miller   22       f                France
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
# 3298         5796        Angel Hood   53     Mle                   NaN
#
#                State                City                               Email  \
# ...

# %%
df['Quantity'].fillna(1)
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3034         3786      Karen Miller   22       f                France
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
# 3298         5796        Angel Hood   53     Mle                   NaN
#
#                State                City                               Email  \
# ...

# %%
df = df[df['Price'] >= 0]
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3034         3786      Karen Miller   22       f                France
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
# 3298         5796        Angel Hood   53     Mle                   NaN
#
#                State                City                               Email  \
# ...

# %%
df = df[df['Price'] > 0]
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3034         3786      Karen Miller   22       f                France
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
# 3298         5796        Angel Hood   53     Mle                   NaN
#
#                State                City                               Email  \
# ...

# %%
df = df[df['Quantity'] >= 0]
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3034         3786      Karen Miller   22       f                France
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
# 3298         5796        Angel Hood   53     Mle                   NaN
#
#                State                City                               Email  \
# ...

# %%
df = df[(df['Age'] >= 0) & (df['Age'] <= 120)]
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675           Unknown   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3034         3786      Karen Miller   22       f                France
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
# 3298         5796        Angel Hood   53     Mle                   NaN
#
#                State                City                               Email  \
# ...

# %%
df = df[(df['Feedback_Score'] >= 1) & (df['Feedback_Score'] <= 5)]
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2657         1802       Brian Simon  114     Mle                Latvia
# 2710         1332  Courtney Jenkins   99       f            Mauritania
# 2955          675           Unknown   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
#
#                State                City                               Email  \
# ...

# %%
df = df[df['Delivery_Date'] >= df['Purchase_Date']]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df['Gender'].replace({'Mle':'Male','m':'Male','f':'Female','Fmale':'Female'})
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df['Payment_Type'].str.strip().str.title()
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df['Account_Status'].str.capitalize().replace({'Actve':'Active','Inactiv':'Inactive','Baned':'Banned'})
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Email'].str.contains(r'^[\w\.-]+@[\w\.-]+\.\w+$', na=False)]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Price'] > 500]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Feedback_Score'] < 3]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[(df['Customer_Loyalty']=='VIP') & (df['Total_Purchase']>1000)]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Account_Status']=='Banned']
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[(df['Delivery_Date'] - df['Purchase_Date']).dt.days > 7]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Category']=='Electronics']
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Country']=='India']
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Quantity'] > 10]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Discount'] > 50]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Price']*df['Quantity'] > 1000]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df.groupby('Customer_ID').apply(lambda x:(x['Price']*x['Quantity']).sum())
df
# Out:
# /tmp/ipython-input-2986372447.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Customer_ID').apply(lambda x:(x['Price']*x['Quantity']).sum())
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# ...

# %%
df.groupby('Product_ID')['Feedback_Score'].mean()
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df.groupby('Customer_ID')['Category'].apply(lambda x:set(x)=={'Electronics'})
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Customer_Loyalty']=='VIP'].groupby('Customer_ID').agg({'Total_Purchase':'sum'}).nlargest(10,'Total_Purchase')
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Customer_ID'].isna()]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df[df['Product_ID'].isna()]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
#                                            Country        State  \
# 0                                              NaN     Arkansas
# 1                                           Uganda        Texas
# 10                                         Germany        Idaho
# 11                                       Hong Kong  Mississippi
# 13                                          Rwanda     Nebraska
# ...

# %%
df['Total_Purchase'] = df['Price'] * df['Quantity']
df
# Out:
# /tmp/ipython-input-3527149425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Purchase'] = df['Price'] * df['Quantity']
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
# ...

# %%
df['Discounted_Price'] = df['Price'] - df['Discount']
df
# Out:
# /tmp/ipython-input-3373522531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Discounted_Price'] = df['Price'] - df['Discount']
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
# ...

# %%
df['Delivery_Duration'] = (df['Delivery_Date'] - df['Purchase_Date']).dt.days
df
# Out:
# /tmp/ipython-input-364271053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_Duration'] = (df['Delivery_Date'] - df['Purchase_Date']).dt.days
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# ...

# %%
df['Age_Group'] = pd.cut(df['Age'], [0,12,19,59,120], labels=['Child','Teen','Adult','Senior'])
df
# Out:
# /tmp/ipython-input-3040997567.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age_Group'] = pd.cut(df['Age'], [0,12,19,59,120], labels=['Child','Teen','Adult','Senior'])
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# ...

# %%
import numpy as np
df['Loyalty_Level'] = pd.cut(df['Total_Purchase'], [0,500,1000,5000,np.inf], labels=['Bronze','Silver','Gold','Platinum'])
df
# Out:
# /tmp/ipython-input-898756400.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Loyalty_Level'] = pd.cut(df['Total_Purchase'], [0,500,1000,5000,np.inf], labels=['Bronze','Silver','Gold','Platinum'])
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# ...

# %%
df['Gender_Code'] = df['Gender'].map({'Male':1,'Female':2,'Other':3})
df
# Out:
# /tmp/ipython-input-956877261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender_Code'] = df['Gender'].map({'Male':1,'Female':2,'Other':3})
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
# ...

# %%
df['Status_Code'] = df['Account_Status'].map({'Active':1,'Inactive':2,'Banned':3})
df
# Out:
# /tmp/ipython-input-2084037219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Status_Code'] = df['Account_Status'].map({'Active':1,'Inactive':2,'Banned':3})
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# ...

# %%
df['Country'] = df['Country'].str.title().str.strip()
df
# Out:
# /tmp/ipython-input-2795497303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'] = df['Country'].str.title().str.strip()
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
# ...

# %%
df['Payment_Type'] = df['Payment_Type'].str.title().str.strip()
df
# Out:
# /tmp/ipython-input-2693498373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Payment_Type'] = df['Payment_Type'].str.title().str.strip()
#       Customer_ID            Name  Age  Gender  \
# 0            1191   Larry Wallace   31   Other
# 1            8287    Shawn Palmer   20    Male
# 10           1379    Louis Cuevas   83     Mle
# 11           7739      Tracy Reed  109    Male
# 13            211     Lynn Garcia   15     Mle
# ...           ...             ...  ...     ...
# 1756         5178    Robert Price  113   Other
# 1950         2268  Derek Martinez  116     Mle
# 2175         3253    Erin Goodwin   58    Male
# 2240         8324     Michael Lee  110  Female
# 2417         3364  Timothy Miller    9    Male
#
# ...

# %%
df = df.applymap(lambda x: x.strip().lower() if isinstance(x,str) else x)
df
# Out:
# /tmp/ipython-input-3639053307.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip().lower() if isinstance(x,str) else x)
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# ...

# %%
df.groupby('Product_ID').apply(lambda x:(x['Price']*x['Quantity']).sum()).nlargest(5)
df
# Out:
# /tmp/ipython-input-566936673.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Product_ID').apply(lambda x:(x['Price']*x['Quantity']).sum()).nlargest(5)
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# ...

# %%
df.groupby('Customer_ID')['Total_Purchase'].sum().nlargest(5)
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...

# %%
df.groupby('Category')['Discount'].mean()
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...

# %%
df.groupby('Category')['Feedback_Score'].mean()
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...

# %%
df['Payment_Type'].value_counts().idxmax()
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...

# %%
df.loc[(df['Price']*df['Quantity']).idxmax()]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...

# %%
df['Customer_ID'].value_counts()[lambda x:x>5]
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...

# %%
df.sort_values(by='Delivery_Duration', ascending=False)
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...

# %%
df.groupby('Product_ID')['Feedback_Score'].agg(['max','min'])
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...

# %%
df.groupby(['Country','Category'])['Total_Purchase'].sum()
df
# Out:
#       Customer_ID            Name  Age  Gender  \
# 0            1191   larry wallace   31   other
# 1            8287    shawn palmer   20    male
# 10           1379    louis cuevas   83     mle
# 11           7739      tracy reed  109    male
# 13            211     lynn garcia   15     mle
# ...           ...             ...  ...     ...
# 1756         5178    robert price  113   other
# 1950         2268  derek martinez  116     mle
# 2175         3253    erin goodwin   58    male
# 2240         8324     michael lee  110  female
# 2417         3364  timothy miller    9    male
#
#                                            Country        State  \
# 0                                              NaN     arkansas
# 1                                           uganda        texas
# 10                                         germany        idaho
# 11                                       hong kong  mississippi
# 13                                          rwanda     nebraska
# ...
